# %%
# styles.ipynb
# ===================================================
# WORKLINK - DESIGN SYSTEM
# ===================================================

# --- COLOUR PALETTE ---
BACKGROUND_COLOR = "#F7F8FC"   # Soft off-white — easier on the eyes than pure white
CARD_COLOR       = "#FFFFFF"   # White card surfaces sit above the background
TEXT_COLOR       = "#1A1A2E"   # Near-black for strong readability
PRIMARY_COLOR    = "#6C63FF"   # Brand purple — used for primary actions & headings
SECONDARY_COLOR  = "#4B44C8"   # Darker purple — hover / active states
MUTED_TEXT       = "#6B7280"   # Grey for secondary labels and metadata
BORDER_COLOR     = "#E2E5F0"   # Subtle border for cards and inputs
ERROR_COLOR      = "#EF4444"   # Red for errors and destructive actions
SUCCESS_COLOR    = "#10B981"   # Green for success states
WARNING_COLOR    = "#F59E0B"   # Amber for warnings

# --- TYPOGRAPHY SCALE ---
# Consistent scale: each step up is clearly distinguishable
FONT_TITLE    = ("Helvetica", 22, "bold")   # Screen headings
FONT_SUBTITLE = ("Helvetica", 14, "bold")   # Card titles, section headers
FONT_BODY     = ("Helvetica", 11, "normal") # General content
FONT_SMALL    = ("Helvetica",  9, "normal") # Metadata, counters, hints
FONT_BUTTON   = ("Helvetica", 11, "bold")   # Button labels
FONT_LABEL    = ("Helvetica", 10, "bold")   # Form field labels — slightly bolder than body

# --- SPACING SCALE ---
# All padding and margins should come from this scale: 4, 8, 12, 16, 24, 32, 48
# This prevents the "hand-tuned per widget" problem.
SP_XS  =  4
SP_SM  =  8
SP_MD  = 12
SP_LG  = 16
SP_XL  = 24
SP_2XL = 32
SP_3XL = 48

# --- REUSABLE COMPONENT STYLE DICTIONARIES ---
# Define once here, import everywhere — no more per-screen overrides.

BTN_PRIMARY = {
    "bg": PRIMARY_COLOR,
    "fg": "#FFFFFF",
    "font": FONT_BUTTON,
    "relief": "flat",
    "activebackground": SECONDARY_COLOR,
    "activeforeground": "#FFFFFF",
    "padx": SP_LG,
    "pady": SP_SM,
    "cursor": "hand2",
    "bd": 0
}

BTN_SECONDARY = {
    "bg": BORDER_COLOR,
    "fg": TEXT_COLOR,
    "font": FONT_BUTTON,
    "relief": "flat",
    "activebackground": "#CBD5E1",
    "activeforeground": TEXT_COLOR,
    "padx": SP_LG,
    "pady": SP_SM,
    "cursor": "hand2",
    "bd": 0
}

BTN_DANGER = {
    "bg": ERROR_COLOR,
    "fg": "#FFFFFF",
    "font": FONT_BUTTON,
    "relief": "flat",
    "activebackground": "#DC2626",
    "activeforeground": "#FFFFFF",
    "padx": SP_LG,
    "pady": SP_SM,
    "cursor": "hand2",
    "bd": 0
}

ENTRY_STYLE = {
    "font": FONT_BODY,
    "bg": CARD_COLOR,
    "fg": TEXT_COLOR,
    "insertbackground": TEXT_COLOR,
    "relief": "solid",
    "bd": 1,
    "highlightthickness": 1,
    "highlightcolor": PRIMARY_COLOR,
    "highlightbackground": BORDER_COLOR
}

LABEL_STYLE = {
    "bg": BACKGROUND_COLOR,
    "fg": TEXT_COLOR,
    "font": FONT_BODY
}

FORM_LABEL_STYLE = {
    "bg": BACKGROUND_COLOR,
    "fg": TEXT_COLOR,
    "font": FONT_LABEL
}

# --- SKILL POOL ---
SKILL_POOL = [
    "Python", "Java", "C++", "JavaScript", "HTML/CSS", "SQL", "Data Analysis",
    "Machine Learning", "Project Management", "UI/UX Design", "Graphic Design",
    "Technical Writing", "Customer Service", "Digital Marketing", "SEO Optimization",
    "Financial Accounting", "Data Entry", "Excel / Spreadsheets", "Public Speaking",
    "Sales & Negotiation", "Cloud Computing (AWS/Azure)", "Cybersecurity",
    "DevOps", "Mobile App Development", "Agile Methodologies", "Content Strategy",
    "Foreign Languages", "Video Editing", "Human Resources", "Network Administration"
]
