# %%
# --- Color Palette ---
BACKGROUND_COLOR = "#FFFFFF" # Pure White background
TEXT_COLOR = "#000000"       # Solid Black text
PRIMARY_COLOR = "#6C63FF"    # Vibrant Purple accent
SECONDARY_COLOR = "#4B44C8"  # Darker Purple for button hover/active states
MUTED_TEXT = "#555555"       # Dark Gray for subtle subheadings
ERROR_COLOR = "#FF3333"      # Red for error validation messages
SUCCESS_COLOR = "#00BB44"    # Green for success messages

# --- Fonts ---
FONT_TITLE = ("Helvetica", 20, "bold")
FONT_SUBTITLE = ("Helvetica", 14, "bold")
FONT_BODY = ("Helvetica", 11, "normal")
FONT_BUTTON = ("Helvetica", 11, "bold")

# --- Component Configurations ---
BUTTON_STYLE = {
    "bg": PRIMARY_COLOR,
    "fg": "#FFFFFF",
    "font": FONT_BUTTON,
    "relief": "flat",
    "activebackground": SECONDARY_COLOR,
    "activeforeground": "#FFFFFF",
    "padx": 15,
    "pady": 6,
    "cursor": "hand2"
}

ENTRY_STYLE = {
    "font": FONT_BODY,
    "bg": "#FFFFFF",
    "fg": TEXT_COLOR,
    "insertbackground": TEXT_COLOR,
    "relief": "solid",
    "bd": 1
}

LABEL_STYLE = {
    "bg": BACKGROUND_COLOR,
    "fg": TEXT_COLOR,
    "font": FONT_BODY
}

# --- Shared 30 Skill Set Pool ---
SKILL_POOL = [
    "Python", "Java", "C++", "JavaScript", "HTML/CSS", "SQL", "Data Analysis",
    "Machine Learning", "Project Management", "UI/UX Design", "Graphic Design",
    "Technical Writing", "Customer Service", "Digital Marketing", "SEO Optimization",
    "Financial Accounting", "Data Entry", "Excel / Spreadsheets", "Public Speaking",
    "Sales & Negotiation", "Cloud Computing (AWS/Azure)", "Cybersecurity", 
    "DevOps", "Mobile App Development", "Agile Methodologies", "Content Strategy",
    "Foreign Languages", "Video Editing", "Human Resources", "Network Administration"
]
